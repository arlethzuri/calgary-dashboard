# %%
import json
filepath = "data/0_raw/enmax/Calgary_City_Limits/Calgary_City_Limits_features.json"

# unpack dict
with open(filepath, 'r') as f:
        obj = json.load(f)[0]

# %%
for i in obj:
    print(i)
    print("-----")
# Out:
# type
# -----
# geometry
# -----
# properties
# -----

# %%
obj
# Out:
# {'type': 'Feature',
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-114.0132905, 51.2124253],
#     [-114.0132772, 51.2052398],
#     [-114.0082935, 51.2052424],
#     [-114.0078611, 51.2052426],
#     [-114.0026622, 51.2052446],
#     [-114.0026621, 51.2022706],
#     [-114.002662, 51.1980122],
#     [-114.0026623, 51.1947689],
#     [-114.0026613, 51.1918178],
#     [-114.0026613, 51.1907732],
#     [-114.0026619, 51.1846281],
#     [-114.0026621, 51.1843543],
#     [-114.0026617, 51.1835323],
#     [-114.0026619, 51.1833518],
#     [-114.002662, 51.1797576],
#     [-114.0022567, 51.1797581],
#     [-114.0022565, 51.1761132],
#     [-114.0018253, 51.1761137],
#     [-114.0018251, 51.1833522],
#     [-114.001825, 51.1835327],
#     [-114.0013934, 51.183533],
#     [-114.0007004, 51.1835334],
#     [-113.9815023, 51.1835415],
#     [-113.9781036, 51.1835429],
#     [-113.9666607, 51.183547],
#     [-113.9582338, 51.1835491],
#     [-113.9552179, 51.1835485],
# ...

# %%
import geopandas
gdf = geopandas.GeoDataFrame.from_features(obj[0]['geometry'])

gdf
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 import geopandas
# ----> 2 gdf = geopandas.GeoDataFrame.from_features(obj[0]['geometry'])
#       4 gdf
#
# File ~/miniconda3/envs/calgary-dev/lib/python3.9/site-packages/geopandas/geodataframe.py:737, in GeoDataFrame.from_features(cls, features, crs, columns)
#     734 if hasattr(feature, "__geo_interface__"):
#     735     feature = feature.__geo_interface__
#     736 row = {
# --> 737     "geometry": shape(feature["geometry"]) if feature["geometry"] else None
#     738 }
#     739 # load properties
#     740 properties = feature["properties"]
#
# TypeError: string indices must be integers
